# %% [markdown]
# # Push Merged Instructions to HuggingFace
#
# This notebook loads the locally built `star-instructions` dataset, lets you inspect it, and pushes it to HuggingFace.
#
# Run `build_merged_instructions.ipynb` first (via SLURM) to generate the dataset.

# %%
import os
import datasets
from dotenv import load_dotenv

load_dotenv()
HF_TOKEN = os.getenv('HF_TOKEN')

DATASET_DIR = 'Notebooks/push_to_hf/built_datasets/star-instructions'
HF_REPO = 'KFUPM-JRCAI/star-instructions'

# %%
star_dataset = datasets.Dataset.load_from_disk(DATASET_DIR)
print(star_dataset)
print(f'Features: {list(star_dataset.features.keys())}')
# Out:
# Loading dataset from disk:   0%|          | 0/206 [00:00<?, ?it/s]
# Dataset({
#     features: ['tags', 'dataset_name', 'dataset_subset', 'answer_choices', 'text_direction', 'prompter_id', 'split_name', 'full_instruction', 'instruction_template', 'instruction_name', 'instruction_tasks', 'instruction_input', 'instruction_output', 'instruction_template_id'],
#     num_rows: 46263378
# })
# Features: ['tags', 'dataset_name', 'dataset_subset', 'answer_choices', 'text_direction', 'prompter_id', 'split_name', 'full_instruction', 'instruction_template', 'instruction_name', 'instruction_tasks', 'instruction_input', 'instruction_output', 'instruction_template_id']

# %% [markdown]
# ## Inspect a few samples

# %%
star_dataset[0]
# Out:
# {'tags': ['Zero-shot COT'],
#  'dataset_name': 'arbml/ANS_stance',
#  'dataset_subset': 'default',
#  'answer_choices': ['disagree', 'agree', 'other'],
#  'text_direction': 'ltr',
#  'prompter_id': 'b',
#  'split_name': 'train',
#  'full_instruction': "For the following task you have to label if the two sentences are of on of the following labels: disagree or agree or other. Sentence 1: هجوم صاروخي يستهدف مطار في طرابلس ويجبر ليبيا على تغيير مسار الرحلات الجوية\xa0 and sentence 2: هدوء الاشتباكات فى طرابلس.\nLet's think step by step:\n|||\ndisagree",
#  'instruction_template': "For the following task you have to label if the two sentences are of on of the following labels: {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}. Sentence 1: {{s1}}\xa0 and sentence 2: {{s2}}.\r\nLet's think step by step:\r\n|||\r\n{{answer_choices[label]}}",
#  'instruction_name': 'Prompt with zero-shot chain of thoughts',
# ...

# %%
star_dataset[-1]
# Out:
# {'tags': ['Example Prompt'],
#  'dataset_name': 'arbml/araData',
#  'dataset_subset': 'default',
#  'answer_choices': ['Tunisian',
#   'Moroccan',
#   'Levant',
#   'general',
#   'Gulf',
#   'Iraqi',
#   'Egyptian'],
#  'text_direction': 'ltr',
#  'prompter_id': 'g',
#  'split_name': 'train',
#  'full_instruction': 'Given the following Arabic text حكامنا الصينعايزين حكام مرتششششششين, in what dialect was it written, choose from the following\nTunisian or Moroccan or Levant or general or Gulf or Iraqi or Egyptian\n|||\nEgyptian',
#  'instruction_template': "Given the following Arabic text {{Sentence}}, in what dialect was it written, choose from the following\r\n{{answer_choices | join(' or ')}}\r\n|||\r\n{{answer_choices[label]}}",
#  'instruction_name': 'Example Prompt',
#  'instruction_tasks': ['dialect identification'],
# ...

# %% [markdown]
# ## Push to HuggingFace

# %%
star_dataset.push_to_hub(HF_REPO, token=HF_TOKEN, private=True)
print(f'Pushed {len(star_dataset)} merged instructions to {HF_REPO}')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B

# %%
from huggingface_hub import HfApi

api = HfApi(token=HF_TOKEN)
api.upload_file(
    path_or_fileobj='Notebooks/push_to_hf/star_instructions_README.md',
    path_in_repo='README.md',
    repo_id=HF_REPO,
    repo_type='dataset',
)
print(f'Uploaded README to {HF_REPO}')
