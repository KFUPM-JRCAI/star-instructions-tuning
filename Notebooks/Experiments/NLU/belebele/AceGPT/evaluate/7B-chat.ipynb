# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1'
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import lm_eval
from lm_eval.tasks import TaskManager
from lm_eval.evaluator import simple_evaluate
from lm_eval.utils import make_table

# %% [markdown]
# # Constants

# %%
TAWJEEH_DATASET_NAME = 'belebele'
HF_EXPERIMENTAL_DATASET_NAME = 'KFUPM-JRCAI/belebele_experimental'
TASK_NAME='NLU'
MODEL_PATH = "/raid_storage/shared_models/AceGPT-7B-chat"
TUNED_MODEL_PATH = None
BATCH_SIZE=64

# %%
MODEL_NAME = MODEL_PATH.split('/')[-1]
TOKENIZER_PATH = MODEL_PATH

# %% [markdown]
# # Building the prompts dataset

# %%
import requests
 
from tqdm.auto import tqdm
 
prompts = None
 
tries = 10
for i in tqdm(range(tries)):
    api_response = requests.get(url='https://promptlab.up.railway.app/api/prompt/list?project_secret_key=6Wirj')
    if api_response.ok:
        prompts = api_response.json()
        break
if not prompts:
    raise Exception('Failed to fetch prompts')
prompts[:5]
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# [{'id': 14888,
#   'tags': ['AI generated'],
#   'name': 'history_based_dialect',
#   'task': {'name': 'dialect identification'},
#   'status': 'SUBMITTED',
#   'template': 'Consider this historical context in the text provided: {{Text}}. Which dialect from the ancient regions does it emerge from? Select from these regions: Levant, North Africa, Egypt, GULF, MSA. ||| {{answer_choices[label]}}',
#   'dataset_name': 'arbml/Arabic_Dialects_Dataset',
#   'dataset_subset': 'default',
#   'answer_choices': ['Levant', 'North Africa', 'Egypt', 'GULF', 'MSA'],
#   'text_direction': 'ltr'},
#  {'id': 14887,
#   'tags': ['AI generated'],
#   'name': 'literary_style_identification',
#   'task': {'name': 'dialect identification'},
#   'status': 'SUBMITTED',
#   'template': 'The narrative style found in the following phrase: {{Text}}, is tied to a specific dialect. Out of Levant, North Africa, Egypt, GULF, MSA, which one do you think it is? ||| {{answer_choices[label]}}',
#   'dataset_name': 'arbml/Arabic_Dialects_Dataset',
#   'dataset_subset': 'default',
#   'answer_choices': ['Levant', 'North Africa', 'Egypt', 'GULF', 'MSA'],
#   'text_direction': 'ltr'},
#  {'id': 14886,
#   'tags': [],
#   'name': 'EmotionClassification-Steps Prompt-Updated',
#   'task': {'name': 'emotion classification'},
#   'status': 'SUBMITTED',
#   'template': 'Task: Read the tweet below and decide which emotion it expresses. The possible emotions are {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}.\r\n\r\nTweet: {{ tweet }}\r\n\r\nSteps:\r\n1. Look for Emotional Words: Identify any words in the tweet that hint at a specific emotion.\r\n2. Decide the Mood: Is the mood positive, negative, or neutral?\r\n3. Pick the Emotion: Choose the emotion that best matches the mood.\r\n\r\n Answer: Provide the emotion {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %} based on the steps. Do not include any additional explanation.\r\n|||\r\n{{ answer_choices[label] }}',
#   'dataset_name': 'emotone_ar',
#   'dataset_subset': 'default',
#   'answer_choices': ['none',
#    'anger',
#    'joy',
#    'sadness',
#    'love',
#    'sympathy',
#    'surprise',
#    'fear'],
#   'text_direction': 'ltr'},
#  {'id': 14885,
#   'tags': [],
#   'name': 'EmotionClassification-Expert In Identifying Emotion Prompt-Updated',
#   'task': {'name': 'emotion classification'},
#   'status': 'SUBMITTED',
#   'template': 'Imagine you are an emotion expert analyzing the following tweet. Carefully read the tweet and use your expertise to determine the emotion being expressed. The possible emotions are {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}.\r\n\r\nTweet: {{ tweet }}\r\n\r\nExpert Approach:\r\n1. Identify Emotional Cues: Look for any words or phrases in the tweet that suggest an emotional state. Think about what kind of feelings these words evoke.\r\n2. Assess the Overall Mood: Consider the mood created by the language used. Is the tweet conveying positive or negative emotions, or is it neutral?\r\n3. Choose the Emotion: Based on the emotional cues and overall mood, decide which emotion from the list fits best.\r\n\r\nAnswer: Provide the most appropriate emotion using your expert analysis  {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}. Do not include any additional explanation.\r\n|||\r\n{{ answer_choices[label]}}',
#   'dataset_name': 'emotone_ar',
#   'dataset_subset': 'default',
#   'answer_choices': ['none',
#    'anger',
#    'joy',
#    'sadness',
#    'love',
#    'sympathy',
#    'surprise',
#    'fear'],
#   'text_direction': 'ltr'},
#  {'id': 14884,
#   'tags': [],
#   'name': 'EmotionClassification-COT Prompt-Updated',
#   'task': {'name': 'emotion classification'},
#   'status': 'SUBMITTED',
#   'template': 'Follow the steps below to classify the emotion expressed in the tweet. The possible emotions are {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}.\r\n\r\nTweet: {{ tweet }}\r\n\r\nStep 1: Interpret the Content: Carefully read the tweet and identify any expressions or language that hint at a specific emotion.\r\nStep 2: Analyze the Emotional Tone: Assess the emotional tone by considering whether the content conveys positive, negative, or neutral feelings.\r\nStep 3: Match with the Emotion List: Compare the emotional tone with the list of possible emotions and choose the one that best aligns with the mood expressed in the tweet.\r\n\r\nAnswer: Provide the most appropriate emotion {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}. Do not include any additional explanation.\r\n|||\r\n{{ answer_choices[label] }}',
#   'dataset_name': 'emotone_ar',
#   'dataset_subset': 'default',
#   'answer_choices': ['none',
#    'anger',
#    'joy',
#    'sadness',
#    'love',
#    'sympathy',
#    'surprise',
#    'fear'],
#   'text_direction': 'ltr'}]

# %% [markdown]
# filter prompts:
# - get only the approved ones
# - get only the ones on the sarcasim detection datasets (emotone_ar,sem_eval_2018_task_1)

# %%
filtered_prompts = list(filter(lambda prompt: prompt['status'] == 'APPROVED' and prompt['text_direction'].lower() == 'ltr', prompts))
len(filtered_prompts)
# Out:
# 223

# %% [markdown]
# ### Get the dataset prompts

# %%
# you can either filter by task or dataset
dataset_prompts = list(
    filter(
        lambda prompt: TAWJEEH_DATASET_NAME in prompt['dataset_name'],
        filtered_prompts,
    )
)
len(dataset_prompts)
# Out:
# 5

# %%
SELECTED_PROMPTS_IDS = [
    14854,
    14853,   
    14801,
    14800,
    14575,
]

# %%
dataset_prompts = list(filter(lambda prompt: prompt['id'] in SELECTED_PROMPTS_IDS, filtered_prompts))
len(dataset_prompts)
# Out:
# 5

# %%
dataset_prompts
# Out:
# [{'id': 14854,
#   'tags': ['', 'original'],
#   'name': 'Passage query and answer with special symbols',
#   'task': {'name': 'multiple choice'},
#   'status': 'APPROVED',
#   'template': 'Given the following passage, query, and answer choices, output the letter corresponding to the correct answer.\r\n###\r\nPassage: {{flores_passage}}\r\n###\r\nQuery: {{question}}\xa0\r\n###\r\nChoices:\r\n{% set choices = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}\r\n{% for choice in choices %}\r\n{{ answer_choices[loop.index0] }}. {{choice}}\r\n{% endfor %}\r\n###\r\nAnswer:\r\n|||\r\n{{ answer_choices[correct_answer_num|int-1] }}',
#   'dataset_name': 'facebook/belebele',
#   'dataset_subset': 'acm_Arab',
#   'answer_choices': ['A', 'B', 'C', 'D'],
#   'text_direction': 'ltr'},
#  {'id': 14853,
#   'tags': [],
#   'name': 'alphabetical instead of numeral choices',
#   'task': {'name': 'multiple choice'},
#   'status': 'APPROVED',
#   'template': 'Consider the following question:\r\n{{question}}\xa0\r\nwith the following context:\r\n{{flores_passage}}\xa0\r\nPlease answer the question selecting one of these answers:\r\n{% set choices = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}\r\n{% for choice in choices %}\r\n{{ answer_choices[loop.index0] }}. {{choice}}\r\n{% endfor %}\r\n|||\r\n{{ answer_choices[correct_answer_num|int-1] }}',
#   'dataset_name': 'facebook/belebele',
#   'dataset_subset': 'acm_Arab',
#   'answer_choices': ['A', 'B', 'C', 'D'],
#   'text_direction': 'ltr'},
#  {'id': 14801,
#   'tags': [],
#   'name': 'read_passage_answer_question',
#   'task': {'name': 'multiple choice'},
#   'status': 'APPROVED',
#   'template': 'Read the following Passage: {{flores_passage}}, \r\nThen answer the question: {{question}}\r\nChoices:\r\n{% set answer_keys = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}\r\n{% for answer in answer_keys %}  \r\n{{ answer_choices[loop.index0] }}. {{ answer_keys[loop.index0] }} {% endfor %}\r\nYour answer is:\r\n|||\r\n{{ answer_choices[correct_answer_num | int-1 ] }}',
#   'dataset_name': 'facebook/belebele',
#   'dataset_subset': 'acm_Arab',
#   'answer_choices': ['1', '2', '3', '4'],
#   'text_direction': 'ltr'},
#  {'id': 14800,
#   'tags': [],
#   'name': 'passage_question_choices',
#   'task': {'name': 'multiple choice'},
#   'status': 'APPROVED',
#   'template': 'Passage: {{flores_passage}}\r\nQueion: {{question}}\r\nChoices:\r\n{% set answer_keys = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}\r\n{% for answer in answer_keys %}  \r\n{{ answer_choices[loop.index0] }}. {{ answer_keys[loop.index0] }} {% endfor %}\r\nAnswer:\r\n|||\r\n{{ answer_choices[correct_answer_num | int -1] }}',
#   'dataset_name': 'facebook/belebele',
#   'dataset_subset': 'acm_Arab',
#   'answer_choices': ['1', '2', '3', '4'],
#   'text_direction': 'ltr'},
#  {'id': 14575,
#   'tags': ['Example Prompt'],
#   'name': 'Example Prompt',
#   'task': {'name': 'multiple choice'},
#   'status': 'APPROVED',
#   'template': 'Given the following document : {{flores_passage}} and the question {{question}} and the following options: {{answer_choices[0]}}. {{mc_answer1}} {{answer_choices[1]}}. {{mc_answer2}} {{answer_choices[2]}}. {{mc_answer3}} {{answer_choices[3]}}. {{mc_answer4}}, the correct answer is:\r\n|||\r\n{{answer_choices[correct_answer_num | int-1]}}',
#   'dataset_name': 'facebook/belebele',
#   'dataset_subset': 'acm_Arab',
#   'answer_choices': ['1', '2', '3', '4'],
#   'text_direction': 'ltr'}]

# %% [markdown]
# ### Download the dataset

# %%
import datasets

# %%
hf_exp_dataset = datasets.load_dataset(HF_EXPERIMENTAL_DATASET_NAME)
hf_exp_dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['link', 'question_number', 'flores_passage', 'question', 'mc_answer1', 'mc_answer2', 'mc_answer3', 'mc_answer4', 'correct_answer_num', 'dialect', 'ds'],
#         num_rows: 900
#     })
# })

# %% [markdown]
# ### Merge the prompts

# %%
from jinja2 import Environment, StrictUndefined

# %%
mc_answer1 = []
mc_answer2 = []
mc_answer3 = []
mc_answer4 = []
for s in hf_exp_dataset['test']:
    mc_answer1.append(s['mc_answer1'])
    mc_answer2.append(s['mc_answer2'])
    mc_answer3.append(s['mc_answer3'])
    mc_answer4.append(s['mc_answer4'])
set(mc_answer3)
# Out:
# {'0',
#  '100 شوط',
#  '10010',
#  '14',
#  '149 ميل بالساعة',
#  '15',
#  '1600',
#  '1759',
#  '1861',
#  '190',
#  '1930',
#  '2',
#  '2243',
#  '27',
#  '3',
#  '35 مم نيجاتيف',
#  '4',
#  '40 ميل في شمال الشرقي',
#  '46 بالمية',
#  '5',
#  '5 أشخاص اعتدوا عليها',
#  '500',
#  '6',
#  '70 كيلومتر',
#  '8 بالمية',
#  '802.11g',
#  'ASUS',
#  'CafeNet El Sol',
#  'ZMapp استخدم كأساس للتجربة',
#  'آية الله علي خامنئي',
#  'أبداً',
#  'أثر التأمين الصحي',
#  'أحجامهم',
#  'أخذ المصور صور لمحطة توقف مال شرطة',
#  'أداء حلو في بداية البطولة',
#  'أذا كان الناس الذين يفهمون اللغة يمكن عدهم',
#  'أذا كانت الخلايا المتأثرة كبيرة',
#  'أذا ما ردت تستخدم الفلاش في الأماكن المظلمة',
#  'أراء النساء',
#  'أراء خبراء آخرين بخصوص العلاج',
#  'أزهار البرقوق',
#  'أسرة فاخرة',
#  'أصدقاء اثنين يسافرون سوه',
#  'أطفال',
#  'أغلب الأعاصير تستمر لأكثر من ثلاث ساعات',
#  'أكتاف المومياء',
#  'أكتشاف قوة قيادة المنظمة',
#  'ألمانيا',
#  'أم',
#  'أماكن معتنين بيها خارج الفندق',
#  'أولاد دوفال الثنين حجوا هواي خلال جلسة الاستماع',
#  'أولمان',
#  'أولومبيات 2012',
#  'أي لاعب طلعت نتيجة فحصه لفيروس كورونا إيجابي',
#  'أيجاد أزواج',
#  'إبقاء الموضوع في مكان معين وفعال',
#  'إذا جان اكو قنابل رح يتم تفجريها ',
#  'إذا جان الراكب عنده وجهة نظر سلبية لكل أنواع وسائل النقل',
#  'إذا جانت الحيوانات الي يصوروها خجولة',
#  'إذا جنت على طيران لوفتهانزا من باريس للولايات الأمريكية',
#  'إذا كان اكو رقابة جمركية',
#  'إذا كان تركيز القوة على الكنيسة',
#  'إريك الأحمر',
#  'إزالة الفرضيات المحتملة',
#  'إسباني',
#  'إسكتلنديا',
#  'إصدار هاتف جديد',
#  'إطعام الحياة البرية',
#  'إعادة تنظيم الجسر',
#  'إغلاق المنبه عند الرنين والرجوع إلى النوم بعد عشرين دقيقة',
#  'إلكترونات وبروتونات',
#  'إمبراطور اليابان',
#  'إنها ملوثة بالفطر',
#  'إيجاد معنى المكان بداخل المنظمة',
#  'إيطاليا',
#  'اتحاد الركبي',
#  'اثنان',
#  'احتياجات داخليه',
#  'احتياجه للاعتكاف وحده',
#  'ازدياد قطع الأجور',
#  'استثماره بالاستكشاف البحري',
#  'استخدام المنظار',
#  'استخدام نقاش مفتوح',
#  'استخدم عمود بالهجوم',
#  'استخدموا التشريع الخاص بالبريد المزعج بالدعوى',
#  'استراليا',
#  'استطلاعات جيولوجية',
#  'استعارة من الدير ',
#  'استقطاعات الأجور',
#  'اسم النوع الجديد',
#  'اصغر شي بمنتزهات جنوب إفريقيا الوطنية',
#  'اعتراف الأمم المتحدة',
#  'اغلب الجزر واجهت هطول أمطار غزيرة',
#  'افضل فنيات صوتية',
#  'افضل ممثلة',
#  'افهم أن الاختلافات الثقافية تنبهك انك ما تصر على موقفك',
#  'اقل حصانة من بقية القلعات',
#  'اكبر حزام أشجار منغروف بالعالم',
#  'اكتأب النمو',
#  'اكثر خط جوي سافرت ويا بتحالف مختلف',
#  'اكو تشكيلات ضئيلة على سطح القمر',
#  'اكو حافلات لنقل المسافرين من المطار لمكان الإقامة',
#  'الآراء المعبرة عن أسلوب الحياة المفرط',
#  'الأداء الممتاز',
#  'الأدمغة',
#  'الأرجل',
#  'الأرض والقمر',
#  'الأرقام الدولية للسلطات',
#  'الأسبان',
#  'الأشخاص اللي عدها لياقة معتدلة عامة راح يستمتعون بهذا النشاط',
#  'الأشخاص اللي يسعون لاكتساب مهارات جديدة',
#  'الأصناف',
#  'الأعضاء',
#  'الأقمار الصناعية',
#  'الأكاديمية السويدية',
#  'الأكل الني',
#  'الألمان والبريطانيين',
#  'الألمان والفرنسيين',
#  'الأماكن الجاذبة ما تأثرت',
#  'الأمريكيين',
#  'الأوكرانيون ',
#  'الأول من مايو',
#  'الأولومبيات الشتوية',
#  'الأوها',
#  'الإجابات بخصوص مستقبل القدس',
#  'الإشعارات',
#  'الإعلام',
#  'الإعلام المحلي',
#  'الاختتامية',
#  'الاصطلاحية',
#  'الاعتقاد',
#  'الاكتئاب',
#  'الاناركيون',
#  'الانضمام الهم بأداء العرض على خشبة المسرح',
#  'البحث عن مواد العناية بالصحة',
#  'البرنامج اليومي',
#  'البناطير',
#  'البوت أبو كعب عالي',
#  'البيرة',
#  'البيرة المحلية',
#  'البيسبول',
#  'التأكد على شنو يرجع بفائدة للأقلية على ألأكثرية',
#  'التحرير',
#  'التحقق من الساعات',
#  'التخريب',
#  'التخفيضات',
#  'التخلص من السفن المصرية',
#  'التخييم خارج الموقع المخصص',
#  'التذوق',
#  'الترطيب الفعال',
#  'التركيز الكبير على قضايا المواد الإباحية',
#  'التركيز على الجرائم الي المفروض تنحل بسهولة',
#  'التركيز على المحصول العالي كحاجز لتقنيات متقدمة ',
#  'التزلج على جبال الألب',
#  'التصاريح تتحصل بس عن طريق الطلبات الفورية',
#  'التضاريس الجبلية',
#  'التعدي',
#  'التقلصات الداخلية والم المعدة',
#  'التكاثر بين الأنواع المختلفة',
#  'التلويح برأس واحد من الحراس',
#  'التلويح وراحة اليد للخارج',
#  'التنوع الاقتصادي',
#  'الثورة البلجيكية',
#  'الجدارية الغير مرغوب بيها على الملكية العامة',
#  'الجدالات الدبلوماسية',
#  'الجدولة',
#  'الجذر',
#  'الجرارات المتخصصة مو ذكية',
#  'الجلسة التشريعية العاجلة',
#  'الجنادب',
#  'الجو',
#  'الجواراني ',
#  'الجيش السوفيتي',
#  'الحانات اللي ما تزورها عادة',
#  'الحجز عن طريق وكالة مختصة بسفر غالاباغوس',
#  'الحدائق النباتية',
#  'الحدث لازم يمتد ل6 اشهر',
#  'الحدود القانونية للبضائع',
#  'الحرارة من جوة الأرض',
#  'الحرب العالمية الثانية',
#  'الحركة',
#  'الحزم الشاملة',
#  'الحساسية من أطوال موجية معينة',
#  'الحفاظ على التوازن',
#  'الحق الضمني بالخصوصية',
#  'الحملات الصليبية',
#  'الحياة البرية',
#  'الحيطان',
#  'الخصائص الفيزيائية',
#  'الخطوط الجوية اللي تختارها اكثر شي من تسافر',
#  'الخوخ',
#  'الخيال العلمي',
#  'الدخان الأبيض',
#  'الدراجات التكاسي هي طريقة زينة للتجول',
#  'الدلالة الدينية',
#  'الدنمارك',
#  'الدوران والضيائية',
#  'الذرات تكون ما مستقرة ',
#  'الذكور',
#  'الرئيس القبلي',
#  'الرجال الأغنياء يتكئون خلال العشاء',
#  'الرجال الرومانيين الأثرياء',
#  'الرماية',
#  'الرمش بالعيون بسرعة',
#  'الرمل',
#  'الرهبان الألمان',
#  'الروحة للمدينة',
#  'الزمن',
#  'الساعات البيولوجية',
#  'السباحة',
#  'السباحة عكس الاتجاه',
#  'السباحة عكس التيار',
#  'الستينيات',
#  'السفر البحثي',
#  'السفر بالسيارة يعتبر خيار زين للناس اللي ما يحبون يمشون بالطرق النمطية والمعتادة',
#  'السفر للخارج',
#  'السفن',
#  'السلطات عرفت عرقيته',
#  'السلوك الوحشي شائع فقط بين الأطفال الذين تم حبسهم من قبل الأهل',
#  'السهول الجنوبية',
#  'السياحة الثقافية',
#  'السياقة بالمناطق شبه الاستوائية',
#  'الشركة',
#  'الشروط',
#  'الشمس',
#  'الصحفيين',
#  'الصخور مكدسة بالثلوج',
#  'الصفات',
#  'الصناعة',
#  'الصور',
#  'الصورة تملئ الشاشة كلها',
#  'الضباط',
#  'الضوء',
#  'الطعام',
#  'الطفرة',
#  'الطفل راح ينسحب من المواقف الاجتماعية',
#  'الطقوس',
#  'الطموح',
#  'الطيات لازم إلها مواقع واضحه',
#  'الطيارة تحطمت في طريقها من أيران إلى أمريكا',
#  'الطيارة تغير مسارها لكوكودا',
#  'الطيارة حاولت تهبط 3 مرات قبل التحطم',
#  'الظباء',
#  'العادات',
#  'العاصفة بعيدة عن اليابسة',
#  'العجائب السبع',
#  'العجلات',
#  'العرض الرئيسي',
#  'العزايم',
#  'العشرات',
#  'العشيات المشوية مطبوخة عادة باستخدام هانجي',
#  'العصور الوسطى الأولى',
#  'العصور الوسطى العليا',
#  'العملية تحدث خلال ساعات النوم العادية',
#  'الغابات الباقية',
#  'الغلاف الجوي للكوكب الأرض',
#  'الفراش أو الأرجوحة الشبكية ينصحون بيها بالتخييم',
#  'الفرق العادية تمتلك أستقلالية أقل من الفرق الافتراضية',
#  'الفرنسية الأساسية الي يعلموها بالمدارس',
#  'الفروسية',
#  'الفهود',
#  'الفوتون',
#  'القدرة على الطيران',
#  'القمح',
#  'القمم',
#  'القوات الفيتنامية دمرت مدينة بنوم بنه',
#  'القوانين الي متساهلة مع جواز وجود المخدرات',
#  'الكبريت المشع ',
#  'الكتابة',
#  'الكلام همين نكدر نترجمه مثل تعابير الوجه',
#  'الكلمات المكتوبة',
#  'الكلمات الي بيها الأحرف سي وجي ممكن تكون مخادعة',
#  'الكنيسة الكاثوليكية الرومانية',
#  'الكهوف الصغيرة',
#  'الكواكب تلف حول الشمس',
#  'الكونغرس الوطني البرازيلي',
#  'اللبن',
#  'اللجنة الرئاسية',
#  'اللغات القديمة',
#  'اللغة',
#  'اللغة الإنكليزية',
#  'اللغة اللاتينية',
#  'اللي ما يحب الشوكولاتة',
#  'اللي يشتغلون بقطاع الدواجن',
#  'المؤدين',
#  'المادة التعليمية',
#  'المالك للنصب التذكاري للحرب',
#  'المبنية',
#  'المتحالفة',
#  'المترشحين لجائزة نوبل للآداب سنة 2016',
#  'المتزلجين اللي خلصوا سباق التعرج العملاق أكثر من اللي خلصوا سباق التعرج العادي',
#  'المتظاهرين',
#  'المتظاهرين طالبوا باستقالة مجلس الانتخابات المؤقت السابق',
#  'المحافظة على اهتمام جمهورهم',
#  'المحافظة على مسافة 25 ياردة من الذيابة',
#  'المحققين الحكوميين',
#  'المحيط',
#  'المحيط المتجمد الشمالي وبحر البلطيق',
#  'المراسلين الصحفيين',
#  'المرح',
#  'المرينيد',
#  'المسارح',
#  'المسافر اللي ما مأمن تأشيرته',
#  'المسافر يتجه لبارو ويحتاج يغادر بعد 11',
#  'المسافرين',
#  'المسافرين اللي بعدهم بمرحلة شهر العسل',
#  'المسافرين يتوفرلهم قائمة بالمضيفين المتوفرين بالمدينة المتوجهين الها',
#  'المستخدم يسوي إعادة توجيه بروتوكول نقل النص الفائق',
#  'المستوى الأولمبي الاحترافي',
#  'المشاكل التنفسية',
#  'المشي',
#  'المصاريف المكلفة',
#  'المصورين',
#  'المقيمين من مناطق ثانية',
#  'المملكة المتحدة',
#  'المن منحوا عقود إعادة الإعمار',
#  'المناخ الحار',
#  'المناطق المزالة من بينينستاد ',
#  'الموسيقى تشتغل بنص الليل',
#  'الموضوعات',
#  'المولات',
#  'الميول للعزلة',
#  'الناس المسافرة لتورونتو',
#  'النتيجة كانت 2-7',
#  'النظام الاستعماري الأمريكي',
#  'النفط',
#  'النقل العام',
#  'الهضاب غالبا مستوية',
#  'الهند',
#  'الولايات المتحدة الأمريكية ',
#  'الويب بروكسي عنده خدمات اقل مقارنة بVPN',
#  'الويلات متضررة بسبب فيشيلا',
#  'الي نأمل تقل بي انبعاثات الكربون',
#  'اليكس اوفيتشكين',
#  'امتلئت الخزانات ووصلت لحدها',
#  'ان جانوا يتبعون بروتوكول مناسب',
#  'انخفاض درجات الحرارة',
#  'انسا (وكالة الأنباء الإيطالية)',
#  'انفجرت',
#  'انه أطول نهر',
#  'انهيار الكهوف الجليدية',
#  'انو هي سفينة كشف الألغام',
#  'ايلول 2021',
#  'بأحد الكازينوهات اللي بالقرب من سانتا في',
#  'بأشهر الشتا',
#  'بأشهر صيف نصف الكرة الشمالي',
#  'بأماكن معينة ببولندا',
#  'بارتفاع الخصر',
#  'بالأماكن اللي صعب يتم ملاحظة الدرون بيها',
#  'بالاوان',
#  'بالبلد اللي تشتغل بيه حاليا',
#  'بالجزر النائية',
#  'بالصيف الهندي',
#  'بالغابات الممطرة',
#  'بالفائز السنوي بلقب المشرف الوطني لعام 2013',
#  'بالقطار أو القارب',
#  'بالمجموعة الثانية',
#  'بالمستشفى',
#  'بالمسرح الأرجنتيني الي يبعد 31 ميل عن بوينس آيرس',
#  'بالمواكب بمهرجانات المعبد',
#  'بالولايات المتحدة',
#  'ببغاء',
#  'بجزيرة إيستوروي',
#  'بداية الحياة',
#  'بدليل جزيئي',
#  'برتغال',
#  'برشلونة',
#  'برق متكرر',
#  'برنامج الأبوة المخططة',
#  'برنامج تعليمي مستقل',
#  'برنامج مصلحة المتنزهات الوطنية والحياة البرية',
#  'بس تقترب من الناس اللي جاي ينظفون اليخت مالتهم',
#  'بعد 25 سنة من العصور الوسطى',
#  'بعد استبدال فليب ماسا',
#  'بعد اكتشاف قبرة',
#  'بعد الخسارة ضد زامبيا',
#  'بعد تأمين الموارد المالية',
#  'بعد خسارته للانتخابات النصفية',
#  'بعد ما اشترت مجموعة فيرجين المصرف',
#  'بعد ما طلع على قناة التسوق التلفزيونية كيو في سي',
#  'بعدما أنهى شوماخر سباقه',
#  'بعض الطرق',
#  'بقاء البرية',
#  'بكتيريا',
#  'بلوخ وبورسيل',
#  'بلورات',
#  'بمحل',
#  'بمهرجان في فناء المعبد',
#  'بموسم مونتيفيديو الممطر',
#  'بموقع تعليمي',
#  'بناء القلعة ما كان نموذجي للفترة الزمنية',
#  'بناء مركبة يتم التحكم بها عن بعد',
#  'بنية صغيره',
#  'بوردن تاون',
#  'بوش',
#  'بيئة الحياة البرية',
#  'بيري ',
#  'بينما كان يسوق بسرعة تتجاوز 160 كم /ساعة',
#  'بيوتهم',
#  'تأثير',
#  'تأثير الاصطدام على الأرض',
#  'تأسيس منصة أطلاق للقوات',
#  'تأشيرة مؤقتة',
#  'تأمين النظر',
#  'تؤثر الأعاصير على مناطق أكبر من بقية العواصف',
#  'تابلت',
#  'تبني أعشاش تتغير بعد 17 يوم',
#  'تبني للأفكار الجمهورية',
#  'تبني موقعك الخاص',
#  'تتمتع بنكهة أفريقية أقل من المدن المحيطة بيها',
#  'تتوقع انو تشتغل وانته هناك، بما ان الاتصال بالإنترنت ممكن يتوفر',
#  'تجاوز تمرين الثلاث دقائق',
#  'تجاوز مسؤولياتهم الحالية ',
#  'تجنب الإيجارات',
#  'تجنب لبس المجوهرات اللماعة',
#  'تجنب هو أي نقاط تفتيش الجوازات',
#  'تحت الهضاب',
#  'تحترق الخيوط الموجودة داخل المصباح',
#  'تحديد سبب المشاكل',
#  'تحذير منشور',
#  'تحصل على 1300 عربة إضافية',
#  'تحصل على رقم من المجتمع المحلي مالتك',
#  'تحليل الدليل الجزيئي',
#  'تحولت الطيارة لأفغانستان',
#  'تخلي المزارعين يتاجرون بمحاصيلهم داخل منطقتهم',
#  'تدفق الماي كان بارتفاع 20 قدم',
#  'تذكر النص',
#  'تذكرة ذهاب وإياب لأثبات طول الإقامة',
#  'ترجمة النص الموجود على الأشياء عن طريق الموبايل',
#  'تروج خدماتك',
#  'تروح ويه شخص ثاني',
#  'تزوج الثنائي قبل شنو ببوفالو',
#  'تسرب الوقود ',
#  'تسع خلفاء للغورو تبعوا المؤسس لهم، غورو نانك',
#  'تسعة',
#  'تسعى لفتح تحقيق خاص',
#  'تشابه الشمس لكوكب زمردة',
#  'تشكيل مستشفيات التعليم',
#  'تصاريح البحث',
#  'تصاميم الطريق',
#  'تصوير المعبود ',
#  'تطلب من الناس فلوس',
#  'تطلبت تعديلات بالموافقة بالأجماع',
#  'تعاني من التعب بسبب الحرارة',
#  'تعتبر أرخص من تذكرة الدرجة الثالثة',
#  'تعتمد الخبرة التعليمية على المتعلم والمعرفة الي يقدمها',
#  'تعتمد على الأحلام الواعية',
#  'تعرض فرد واحد لإصابة من اصل 12 فرد بالطاقم',
#  'تغييرات حدثت بالقانون العالمي',
#  'تغييرات رسمية يسوها القاضي غلين',
#  'تغييرات ضرورية بالمؤسسة',
#  'تفتقر الدولة إلى حضور ممثلين',
#  'تفجير القنابل بالمعالم ببلدين',
#  'تقبل الأعراف المجتمعية',
#  'تقدر تتحمل أوزان اكبر',
#  'تقديم الإقامة والسفر بشكل مجاني',
#  'تقريبا 2000',
#  'تقليل انبعاثات الكربون ',
#  'تقليل حجم مستوى الخطر المحتمل',
#  'تقنية تعتمد على الرادار الأرضي',
#  'تكدر تلكه مراكز تسوق حديثة وكنايس قديمة ',
#  'تكرار التوكيدات',
#  'تكون الأسرع بالرجوع للأرض',
#  'تم أعطاء الماء للمسافرين',
#  'تم إلقاء البض عليه من قبل البريطانيين',
#  'تم اختراعها من قبل الملك الرابع لأسرة جوسون',
#  'تم الإشراف على الرماة من قبل الحرس',
#  'تم انتهاك القوانين الرقابية',
#  'تم طرد بيكيه جونيور بعدها',
#  'تمت محاربة حروب نابليون',
#  'تمت مهاجمته بعمود',
#  'تمدد حراري',
#  'تمشي سرعة على المنحدرات الحادة',
#  'تنزيل بيانات اللغة',
#  'تنشيط النفاثات',
#  'تنصب خيمة بالمدينة أو ملكية خاصة',
#  'توصيات لحماية حدود العراق',
#  'توظيف العمال الصينيين في مزارعها',
#  'توفر رفقة',
#  'توفير نوع العدسات المطلوبة',
#  'توقيع قائمة المصوتين',
#  'توكيد على حالة وعي سعيدة',
#  'ثلاث أصناف مختلفة',
#  'ثنينهم الذكور والإناث يقتلون مميتين جدا لفرائسهم',
#  'جاذبية أيو تجذب اكثر، لهذا وزنك يكون اكثر',
#  'جاك ليتون',
#  'جانت اكو رياح قوية',
#  'جانت عنده لعبة يوم الأحد',
#  'جانوا النزلاء هناك علمود ليلة موسم الحج',
#  'جانوا يصرخون ويبجون',
#  'جاهزية منطقة الحرب',
#  'جدالات أذربيجان الدبلوماسية',
#  'جدول عمل يسمح بالسفر بشهر ديسمبر ويناير',
#  'جزر التشاتام',
#  'جزيرة باون',
#  'جزيرة هونغ كونغ',
#  'جسمه كله مغطى بالريش',
#  'جسيمات زغيرة',
#  'جمع الغذاء',
#  'جنوب إفريقيا واستراليا',
#  'جنوب المحيط الهادئ',
#  'جودة الصور مشابهه لعدسات الطول البؤري الثابت',
#  'جورج نيكولاكوبولوس',
#  'جوردون جوندرو',
#  'جوسون ',
#  'جولات يسووها مرشدين محليين',
#  'جون كير',
#  'جون نيكسن',
#  'جوهانسبرغ',
#  'حائز على الميدالية الذهبية مرتين',
#  'حاسة شمهم ضعيفه',
#  'حافز الهجوم',
#  'حالته مستقرة',
#  'حتى تكون من المعالم الرئيسية',
#  'حتى يتفادون التأثير على الأعمال المحلية',
#  'حتى يحصلون على الانتباه من قبل والديهم',
#  'حجز رحلة درجة أولى غير مباشرة',
#  'حجم الثلج الزائد على المنحدرات الحادة',
#  'حرب الخلافة الأسبانية',
#  'حرية شركة «إيه أو إل» بتطوير السوق بطريقتها الخاصة',
#  'حصل على درجة',
#  'حضارة نهر السند',
#  'حفلة موسيقية',
#  'حقبة هان جين',
#  'حليب جوز الهند واللحم',
#  'حملتها لوفد مقاطعة بوينس آيرس',
#  'حوالي 600 سنة مضت',
#  'حيوانات أليفة متأثرة',
#  'خبره',
#  'خريطة الزلازل العالمية',
#  'خشب التنوب',
#  'خطر جدا',
#  'خلال حركة المد المنخفضة',
#  'خلي أجهزة الاستشعار قريب من التلفزيون',
#  'خمس منحدرات',
#  'خمسة عشر مرة',
#  'خنازير',
#  'خيمة',
#  'دخل العملة الأجنبية',
#  'دراسة التاريخ',
#  'دكتور',
#  'دلالاتها الثقافية',
#  'دلّوا سواق الدراجات لطرق ثانية',
#  'دمرت النار العديد من أثار القلعة',
#  'دمرها',
#  'دوران الدراويش',
#  'دولة المدينة',
#  'ديفي',
#  'ذرات',
#  'ذرتان من الهيدروجين وذرتان من الأوكسجين',
#  'ذكر يبلغ من العمر 43 عاما',
#  'رأي اللورد بايرون الإيجابي',
#  'رأي جون جرانت',
#  'رؤية سيام ريب',
#  'رئيس باكستان',
#  'رائد الفضاء رقم 11',
#  'راجو خانديلوال',
#  'راح تأثر بشكل كبير على أداءهم',
#  'راح يستخدم برا البيت',
#  'راديو استرونت',
#  'راننج تاورز براغ',
#  'رحلة راح تكون بيها اللغة حاجز',
#  'رفض الاعتراف بالديانات الهندية الأخرى',
#  'رفع مكانته',
#  'رفعت الدعوى بسنة 2003',
#  'روسي',
#  'رومني',
#  'رياضات المغامرة',
#  'ريش بالغين',
#  'زعيم للحزب الوطني الديموقراطي',
#  'زملاءهم من السجناء الجرحى',
#  'زوار ثانيين معروفين أو مشهورين',
#  'زوجين عمرهم بالسبعينات',
#  'زيادة عدد الشوب الأحدب',
#  'زيارة متحف علوم',
#  'ساحة القديس بطرس',
#  'ساعات عمل مرنة',
#  'سانتوريني',
#  'سببت شكاوى كبيرة من قبل مستخدميها',
#  'سبعة',
#  'سترابو',
#  'ستيوارت',
#  'سرج جلدي',
#  'سرقة ألآف القطع الأثرية من قبرة',
#  'سكان أروكانيا',
#  'سكان الكهوف',
#  'سكايب',
#  'سمعة للحياة البرية',
#  'سمك الثلج',
#  'سناتر التسوق',
#  'سوفينيون بلانك من نيوزيلندا',
#  'شبكة واحدة (ويب)',
#  'شبنم',
#  'شبه الجزيرة',
#  'شحنة سالبة',
#  'شخص مخطط يشتغل أونلاين وهو مسافر',
#  'شخص منغلق التفكير',
#  'شرايح قابلة للطباعة',
#  'شرب الكحول باعتدال',
#  'شرق',
#  'شركة LATAM',
#  'شروق الشمس',
#  'شعب التاينو',
#  'شعب الماوري من بولنيزيا ',
#  'شكر جوز الهند',
#  'شلون رح تتم مشاركة نتائج التحليل البياني',
#  'شنايدر',
#  'شنو هي المواد العضوية',
#  'شهادة برياضة التجديف ',
#  'شيري شام',
#  'صادرات الفحم',
#  'صار بحفلة بتكساس',
#  'صالة تعرض ترفيه ليلي',
#  'صحة النساء',
#  'صحته زينة ويكدر يتواصل عن بعد',
#  'صناعة العدسات',
#  'صوت أعلى',
#  'صوتوله مرة كأفضل لاعب بتاريخ الفريق',
#  'ضرب الكف',
#  'ضغط أقل',
#  'ضيف مسافر ويه أطفال صغار',
#  'طالب دولي',
#  'طباعة إعلانات غير مخولة',
#  'طراز قديم',
#  'طرد المسبار كان ناجح',
#  'طرق معينة للتعليم أفضل من غيرها',
#  'طلب هيروستراتوس تغطيه تكاليف أعاده البناء',
#  'طول الليل',
#  'طول تعافي الحالة',
#  'طيارة حربية',
#  'ظروف زينة',
#  'عبر جنوب شرق أوروبا',
#  'عدد الناس الي ممكن يعديها الشخص المصاب بالعدوى',
#  'عدد قليل من المعدات',
#  'عدد كبير من المؤسسات',
#  'عدد مستخدمين «إيه أو إل» راح يكون محل منافسة مع عدد مستخدمين ياهو ومايكروسوفت ',
#  'عدم استنشاق الدخان الأبيض',
#  'عدم التصرف تجاه المشاكل الداخلية الي تم اكتشافها',
#  'عدم الحكم على الآخرين بمجرد النظر اليهم',
#  'عروق',
#  'عقوبات تمنع شراء الطائرات',
#  'علاقتهم مع الأطفال الآخرين',
#  'علامة تشبه حرف v',
#  'على ظرف',
#  'على ظهر الحصان',
#  'على هدف الطيارة الأولى',
#  'عمل كعامل مسيطر بتجربة PALM',
#  'عمليات الطريق',
#  'عمليات متناقضة',
#  'عملية تكثيف حادة',
#  'عندما ترسل الأشياء كأمتعة مفحوصة',
#  'عيد ميلاد الإله',
#  'غاز',
#  'غلي الماي لمدة دقيقة واحدة',
#  'فاز موراي بالمجموعة الثانية',
#  'فتحوهم لأصحاب الدراجات',
#  'فحص المسالخ بشكل مستمر',
#  'فحص موقع الضحية',
#  'فرشة للتخييم',
#  'فرضت القوات الأمريكية سيطرتها',
#  'فرنسا',
#  'فصائل ذو قدميين',
#  'فلم 56 × 56 مم',
#  'في الحفرة الأولى',
#  'في الساحة',
#  'في السوق',
#  'في العاشر من آذار',
#  'في صندوق السيارة',
#  'في وادي الراين',
#  'في يوم الاثنين',
#  'فيتنام غزت كمبوديا في بداية القرن الثامن عشر',
#  'فيثاغورس',
#  'قارب',
#  'قاعدة المصباح',
#  'قبل 11:00',
#  'قبل 3.9 مليون عام',
#  'قبل الزلزال',
#  'قبل تقاعد شوماخر',
#  'قبل لا تطلع سيارة الأمان',
#  'قبل لا يوصل لذروته',
#  'قدرة القفز ',
#  'قدرة تايوان بالسيطرة على مناطق الساحلية؟',
#  'قراءات مستوى البحر تأثرت',
#  'قسم الإطفاء الياباني',
#  'قضاء الرحلة كلها في ممتلكات ديزني',
#  'قطر الكهوف',
#  'قطط متوسطه الحجم',
#  'قطعت أمدادات الألمان',
#  'قفز',
#  'قلوي',
#  'قواعد المنشأ',
#  'قول النكات',
#  'قيمتهم تُقدّر بـ 11000 دولار اكثر من الذهب',
#  'كارتر',
#  'كان منطلق من مدار مجهول',
#  'كان هناك غموض في الدستور',
#  'كان هناك هواية شغب',
#  'كان يخاف تأثر سلبا على صحته',
#  'كرة السلة',
#  'كرة النور',
#  'كروزيرو',
#  'كريغسمارين',
#  'كسر كرسي بمحاولة خروجه',
#  'كعب',
#  'كل الدول القريبة للجنوب الأفريقي تقريبا مستقرة',
#  'كل المناطق في شمال شرق أفغانستان',
#  'كل خدمات السكك الحديدية',
#  'كل مندوبي الولاية',
#  'كلب',
#  'كلفة الفيزا الإفريقية',
#  'كمية أيونات الهيدروجين في المادة الكيميائية',
#  'كمية من الحشود',
#  'كن مهذب',
#  'كوفرسيانو',
#  'لآلاف السنوات',
#  'لا ليونا',
#  'لازم تتبدل جنيهات فوكلاند بعد مغادرة الجزر',
#  'لازم تعبر من كهف بالقمة',
#  'لازم تكون منتبه من تضغط المفاتيح وبنفس الوقت تحافظ على استرخاء ايدك',
#  'لاعب من لاعبين اوتاه جاز كان أداءه أقل من المستوى المطلوب بعد ما تأكد إصابته بفيروس كورونا',
#  'لامب',
#  'لطرح الأسئلة',
#  'لعب ويا بارتيزان لحد 1995',
#  'لقاحات الالتهاب الدماغ',
#  'للتشريعات',
#  'للتكنولوجيا تأثير متأصل بالمجتمع',
#  'للمراسيم الدينية',
#  'لم يتم سماعه من قبل ويلز',
#  'لندن',
#  'له نسبه عرض ألى ارتفاع مختلفه من الكثير من التنسيقات الشائعة',
#  'لو بيكولو أمر انو يكتلو',
#  'ما جانوا النزلاء هناك ليلة الحج',
#  'ما ممكن الوصول الها جوا',
#  'ما يفتشون عنها',
#  'ما يمكن تكون مخزونة على موقع إلكتروني',
#  'ماريو ليميكس',
#  'ماسيج كريزيل',
#  'ماكو هواية بوميرانغ باستراليا',
#  'مانجولا',
#  'متشابهات بالكتابة والمفردات',
#  'متطلبات الفيزا',
#  'متعدد الخلايا',
#  'متوقعين هجوم',
#  'مجرى الدم يتدفق مع المشابك الشريانية',
#  'مجموعة فيرجين عرضت دعم طارئ للبنك خلال أزمة الرهن العقاري',
#  'محيط حيوي مستقر',
#  'مخططين يوفرون 1300 عربة إضافية',
#  'مدارس في هاواى',
#  'مدخل شارع داونينغ',
#  'مدنها الرئيسية هي راروتونجا وإيتوتاكي',
#  'مدير لونا',
#  'مراقبة التنصيب',
#  'مراقبة وضع الضحية',
#  'مراقبين الطيور محظورين بالإصابة',
#  'مركبات',
#  'مركز المدينة',
#  'مركز مدينة هونغ كونغ',
#  'مسؤول بشركة الغاز',
#  'مسؤول بشركة الغاز ',
#  'مسؤولين تكساس',
#  'مساعدة',
#  'مسافة قفزتهم',
#  'مسافر ذو ميزانية محدودة مهتم بكلفة المنتزهات',
#  'مستوى النشاط',
#  'مستوى خبرة المتزلج',
#  'مستويات الحدة',
#  'مستويات الطاقة ما مستقره',
#  'مسلحين',
#  'مسودة سياسة',
#  'مشاهدة الرسوم المتحركة',
#  'مشروبات مجانية',
#  'مصدر لم يكشف عنه',
#  'مصر ',
#  'مصرف دويتشه',
#  'مضايق شديدة الانحدار',
#  'مطاعم بالموقع',
#  'مطاعم تطل على الحديقة ',
#  'مطويات أوريجامي تتطلب مطويات متعاكسة',
#  'معبد سان دييجو',
#  'معرفة الحقائق',
#  'معزولة',
#  'مفيدة بتدوير الأموال',
#  'مقاتلين داعش',
#  'مقعر',
#  'مقلوبة',
#  'مكتب بريد محلي',
#  'ملاحظه المربعات الصغار',
#  'ملتزمين بالدستور الباكستاني',
#  'ممكن استخدام الجلاب الي تستنشق المخدرات بدون إشعار',
#  'ممكن تتحول لإعصار',
#  'ممكن تستمر لأحداث ل6 اشهر',
#  'ممكن تصير لخبطة بين جناطك وجناط شخص ثاني ',
#  'ممكن تكون اكو حاجة لزيارة مكاتب الهجرة',
#  'ممكن يكون عند الصين ناتج محلي إجمالي اكبر من الولايات المتحدة بالنهاية',
#  'ممكن يكون نتيجة لتقلص القمر',
#  'ممكن يكونون مزيفين',
#  'ممكن يهيجون من يتقرب الناس منهم',
#  'من تخضع الدولة لقيادة جديدة',
#  'من تكون البيانات عن بعد غير ضرورية',
#  'من تنزل من غيوم العاصفة',
#  'من مواطنين البلد اللي راح يزورونه',
#  'من يروح الأطفال بالمشي لمسافات طويلة',
#  'من يكون المسافر يحجي لغة الناطق بيها البلد المتوجهله',
#  'من يكون منسوب الماي عالي',
#  'منازل مقاومة للفيضانات',
#  'مناظر درامية للشلالات',
#  'مناقشات بخصوص دليل شاهد عيان',
#  'منشأة سنترال بوكينج',
#  'منطقة نورث هاربور',
#  'منع القرصنة',
#  'منع بيع أو تأجير ألعاب الفيديو العنيفة للقاصرين خارج كاليفورنيا',
#  'موقع',
#  'موقع التراث العالمي',
#  'موقع زلزال ٢٠١٠',
#  'موقع نائي',
#  'موقعها يحاوط بينينستاد',
#  'مياه',
#  'ميلر',
#  'نادال يغلب راونيك',
#  'نادرا ما يتم الالتزام بحدود السرعة',
#  'ناس اكثر راح تنصاب',
#  'نتيجة تبلغ 600 ميغابت بالثانية',
#  'نشاط خارج المركبة الفضائية',
#  'نطق كلمات فرنسية معينة',
#  'نظرة بتطور الريش',
#  'نقص المساعدة',
#  'نقل المواد عبر المحيط الأطلسي',
#  'نقلوا من مستشفى في مدينة كامبرج إلى مستشفى ثانية بمدينة بجريت يارموث',
#  'نهر مارا',
#  'نوع الطفرة',
#  'نيفادا',
#  'هم مستعدين حتى يخوضون التحدي',
#  'هناك العديد من الفنادق ومراكز المؤتمرات',
#  'هو حدث فني يصير بالصيف عبر جنوب شرق أوروبا',
#  'هو ساق فوق الجسر سبع مرات فقط',
#  'هو متفائل انو الاستنتاجات ممكن تأدي لعلاج',
#  'هواية حافلات تغادر خلال اليوم',
#  'هوكي الجليد',
#  'هي اللغة اللي ديفضلوها الناس ببرشلونة',
#  'هي لغات مبنية حتى تطور سيناريوهات تواصل صعبة ',
#  'وافق مفوض التجارة والصناعة بالاتحاد الأفريقي ',
#  'وانته خارج نطاق التغطية',
#  'وتمركزو بشمال شرق شبه الجزيرة',
#  'وجود الجيش بالوادي',
#  'وجود حياة أخرى على بقية الكواكب',
#  'وحتى تظهر المحادثات البسيطة مختلفة التنسيق',
#  'ورة ما ضيع أخته',
#  'وسط مدينة أوكلاند',
#  'وسط مدينة فانكوفر',
#  'وضع بيضة',
#  'وعي واسع من المحيطين',
#  'ولد',
#  'ونغ كان سينغ ولي هسين لونج',
#  'وين تقدم',
#  'يأخذ وقتة بحل المشكلة',
#  'يأكدون مدة إقامة المسافر',
#  'يؤثر على الماء',
#  'ياباني',
#  'يتبعون فريستهم خلال الليل',
#  'يتبنى اتباع الصوفية ممارسات تساعد تنشئة بصيرتهم في الواقع الإلهي',
#  'يتشاركون بنفس المنطقة الزمنية',
#  'يحجز مباشرة عبر الخطوط الجوية',
#  'يحصلون على تصريح انغكور',
#  'يحفظون نسخة بلابتوبهم',
#  'يرتبط الذكور والإناث ارتباط وثيق',
#  'يرفع الفريقين تقاريرهم لإدارة مخفية',
#  'يستخدموها لحمل الأوزان الثقيلة',
#  'يسوون حفلة ربيعية للتجمعات',
#  'يشوفون أهم الأماكن',
#  'يشير إلى تشكيل مساحات جديدة',
#  'يصيرون مخروط قمعي بعد ما يلمسون الأرض',
#  'يعبر طريق سريع مزدحم',
#  'يعدل السكان تكيفهم مع بيئتهم الجديدة',
#  'يعرف أيضا كمشروع قائم على التعليم',
#  'يعطي الضوء والحرارة',
#  'يغطون تكاليف السفر باخر لحظة',
#  'يغيرون يومية أعشاشهم',
#  'يقارن الأسعار بين عدة شركات سفر',
#  'يكدر يكمل السباق بأقل من دقيقتين',
#  'يكملون المشي بالفضاء',
#  'يمتثلون لنفس قوانين بلدهم',
#  'يمكن ان يوجد اقل ماريا بالجانب البعيد',
#  'ينشر العدوى',
#  'يهدرون طاقتهم وهم يلاحقون السراب'}

# %%
def apply_template(prompt_template, sample):
    try:
        template = prompt_template['template']
        sample['answer_choices'] = prompt_template['answer_choices']
        env = Environment(undefined=StrictUndefined)
        if "|||" not in template:
            raise ValueError("No ||| dividor")
        template = env.from_string(template)
        rendered_template = template.render(**sample)
        return rendered_template
    except Exception as e:
        print(prompt_template)
        print(sample)
        raise e

# %% [markdown]
# Perform generation on one example prompt, for experimentation

# %%
example_prompt_template = dataset_prompts[0]
print(apply_template(example_prompt_template, hf_exp_dataset['test'][1]))
# Out:
# Given the following passage, query, and answer choices, output the letter corresponding to the correct answer.
# ###
# Passage: """جزر كوك هي دولة جزرية مرتبطة بشكل حر بنيوزيلندا، وتصير ببولينيزيا وسط جنوب المحيط الهادئ. هي أرخبيل بي 15 جزيرة منتشرة على مساحة تزيد عن 2.2 مليون كيلومتر مربع من المحيط. تتشارك بنفس المنطقة الزمنية مثل هاواي، وتعتبر أحياناً هذي الجزر بأنها """"هاواي أسفل"""". على الرغم من كونها أصغر بالحجم، بس تذكر بعض الزائرين القدامى اللي جايين من هاواي ما قبل قيام الدولة قبل وجود كل الفنادق السياحية الكبيرة وغيرها من التطويرات. ماكو بجزر كوك أي مدن بس تتكون من 15 جزيرة أهمها راروتونجا وإيتوتاكي."""
# ###
# Query: أي من التالي ما يوصف جزر كوك بشكل دقيق؟
# ###
# Choices:
#
#
# A. اصغر من هاواي
#
# B. عبارة عن أرخبيل
#
# C. مدنها الرئيسية هي راروتونجا وإيتوتاكي
#
# D. البلد الجزري يتشارك نفس المنطقة الزمنيه ويه هاواي
#
# ###
# Answer:
# |||
# C

# %% [markdown]
# merge prompts

# %%
for prompt in dataset_prompts:
    prompt['merged_samples'] = list(
        map(
            lambda sample: apply_template(prompt, sample),
            # hf_exp_dataset['test'].select(range(100)),
            tqdm(hf_exp_dataset['test']),
        )
    )
    prompt['original_samples'] = list(hf_exp_dataset['test'])
# Out:
#   0%|          | 0/900 [00:00<?, ?it/s]
#   0%|          | 0/900 [00:00<?, ?it/s]
#   0%|          | 0/900 [00:00<?, ?it/s]
#   0%|          | 0/900 [00:00<?, ?it/s]
#   0%|          | 0/900 [00:00<?, ?it/s]

# %% [markdown]
# # Evaluate on each prompt and report the results

# %%
from datasets import DatasetDict
import re

def create_hf_dataset(dataset_prompt, columns=None):
  if columns is None:
    columns = ['text', 'label','choices']
  texts = []
  labels = []
  choices = []
  for i,merged_sample in enumerate(dataset_prompt['merged_samples']):
    # prefix= merged_sample.split('|||')[0].replace('\n', ' ')
    prefix= merged_sample.split('|||')[0]
    # remove multi spaces
    # prefix = re.sub(r'\s+', ' ', prefix)
    prefix = prefix.strip()
    # add new line after prefx (this turns out to have a large effect on some prompts)
    # prefix = prefix+'\n'
    output = merged_sample.split('|||')[1].replace('\n', '').strip()
    example_choices = dataset_prompt['answer_choices']
    texts.append(prefix)
    labels.append(output)
    choices.append(example_choices)
  dataset = DatasetDict({ 'test' : datasets.Dataset.from_dict({
      columns[0]: texts,
      columns[1]: labels,
      columns[2]: choices,
  })})
  return dataset

# %%
dataset = create_hf_dataset(dataset_prompts[0])
dataset['test'][1]['text']
# Out:
# 'Given the following passage, query, and answer choices, output the letter corresponding to the correct answer.\n###\nPassage: """جزر كوك هي دولة جزرية مرتبطة بشكل حر بنيوزيلندا، وتصير ببولينيزيا وسط جنوب المحيط الهادئ. هي أرخبيل بي 15 جزيرة منتشرة على مساحة تزيد عن 2.2 مليون كيلومتر مربع من المحيط. تتشارك بنفس المنطقة الزمنية مثل هاواي، وتعتبر أحياناً هذي الجزر بأنها """"هاواي أسفل"""". على الرغم من كونها أصغر بالحجم، بس تذكر بعض الزائرين القدامى اللي جايين من هاواي ما قبل قيام الدولة قبل وجود كل الفنادق السياحية الكبيرة وغيرها من التطويرات. ماكو بجزر كوك أي مدن بس تتكون من 15 جزيرة أهمها راروتونجا وإيتوتاكي."""\n###\nQuery: أي من التالي ما يوصف جزر كوك بشكل دقيق؟\xa0\n###\nChoices:\n\n\nA. اصغر من هاواي\n\nB. عبارة عن أرخبيل \n\nC. مدنها الرئيسية هي راروتونجا وإيتوتاكي\n\nD. البلد الجزري يتشارك نفس المنطقة الزمنيه ويه هاواي\n\n###\nAnswer:'

# %%
from lm_eval.models.huggingface import HFLM
if 'lm_obj' not in locals():
    lm_obj = HFLM(
        pretrained=MODEL_PATH,
        trust_remote_code=True,
        parallelize=True,
        device_map="auto",
        tokenizer=TOKENIZER_PATH,
        batch_size=BATCH_SIZE,
    )
# Out:
# 2024-11-28:10:11:37,670 INFO     [huggingface.py:483] Using model type 'default'
# 2024-11-28:10:11:40,998 INFO     [huggingface.py:350] Model parallel was set to True, setting max memory per GPU to {0: 84523417600, 1: 84523417600} and device map to 'auto'

# %%
def evaluate_tasks(tasks,dataset_sub_path=TAWJEEH_DATASET_NAME):
    # MAKE SURE THE NOTEBOOK IS RUNNING FROM THE PROJECT ROOT!
    task_manager = TaskManager(include_path=f"eval_harness_extra_tasks/{dataset_sub_path}")
    results = simple_evaluate(  # call simple_evaluate
        model=lm_obj,
        tasks=tasks,
        num_fewshot=0,
        task_manager=task_manager,
        # limit=1000,
    )
    return results

# %%
import json

def create_and_evaluate_single_prompt(prompt, save_results=True, force_re_evaluate=False):
    prompt_id = prompt['id']
    if TUNED_MODEL_PATH:
        results_dir = f'evaluation_results/{MODEL_NAME}-tuned/{TASK_NAME}/{TAWJEEH_DATASET_NAME}'
    else:
        results_dir = f'evaluation_results/{MODEL_NAME}/{TASK_NAME}/{TAWJEEH_DATASET_NAME}'
    prompt_results_file_path = f'{results_dir}/prompt_{prompt_id}.json'
    
    # Check if results exist and handle based on parameters
    if os.path.exists(prompt_results_file_path) and os.path.getsize(prompt_results_file_path) > 0:
        if not force_re_evaluate:
            print(f"Skipping prompt {prompt_id} - results already exist")
            with open(prompt_results_file_path, 'r') as f:
                prompt_results = json.load(f)
                print(make_table(prompt_results))
                return prompt_results
        else:
            print(f"Force re-evaluate enabled - reevaluating prompt {prompt_id}")
    
    # Create dataset and task files
    dataset = create_hf_dataset(prompt)
    
    # Save dataset
    dataset_dir = f'experimental_hf_datasets/{TAWJEEH_DATASET_NAME}/prompt_{prompt_id}'
    os.makedirs(dataset_dir, exist_ok=True)
    dataset['test'].to_parquet(f"{dataset_dir}/data.parquet")
    
    # Create YAML configuration
    yaml_text = f'''task: {TAWJEEH_DATASET_NAME}_prompt_{prompt_id}
dataset_path: experimental_hf_datasets/{TAWJEEH_DATASET_NAME}/prompt_{prompt_id}
output_type: multiple_choice
test_split: train
doc_to_text: text
doc_to_choice: choices
doc_to_target: label
metric_list:
  - metric: acc
    aggregation: mean
    higher_is_better: True
  - metric: acc_norm
    aggregation: mean
    higher_is_better: true
metadata:
  version: 1.0'''
    
    # Save YAML
    yaml_dir = f'eval_harness_extra_tasks/{TAWJEEH_DATASET_NAME}'
    os.makedirs(yaml_dir, exist_ok=True)
    with open(f'{yaml_dir}/prompt_{prompt_id}.yaml', 'w') as f:
        f.write(yaml_text)
    
    # Evaluate single prompt
    evaluation_task_name = f'{TAWJEEH_DATASET_NAME}_prompt_{prompt_id}'
    prompt_results = evaluate_tasks(tasks=[evaluation_task_name])
    
    print(make_table(prompt_results))
    
    # Save results if save_results is True
    if save_results:
        os.makedirs(results_dir, exist_ok=True)
        with open(prompt_results_file_path, 'w') as f:
            json.dump(prompt_results, f, ensure_ascii=False, indent=4, 
                     default=lambda o: '<not serializable>')
        print(f"Saved results for prompt {prompt_id}")
    else:
        print(f"Results not saved for prompt {prompt_id} (save_results=False)")
    
    print(f"Completed evaluation for prompt {prompt_id}")
    return prompt_results

# %%
def evaluate_all_prompts_sequentially(dataset_prompts, **kwargs):
    print(f"Starting sequential evaluation of {len(dataset_prompts)} prompts")
    all_results = {}
    
    for i, prompt in enumerate(dataset_prompts, 1):
        print('-' * 80)
        print(f"\nProcessing prompt {i}/{len(dataset_prompts)} (ID: {prompt['id']})")
        print("Template:", prompt['template'])
        print('-' * 80)
        
        prompt_results = create_and_evaluate_single_prompt(prompt, **kwargs)
        all_results[f"{TAWJEEH_DATASET_NAME}_prompt_{prompt['id']}"] = prompt_results
    
    return {'results': all_results}

# %%
all_results = evaluate_all_prompts_sequentially(dataset_prompts=dataset_prompts)
# Out:
# Starting sequential evaluation of 5 prompts
# --------------------------------------------------------------------------------
#
# Processing prompt 1/5 (ID: 14854)
# Template: Given the following passage, query, and answer choices, output the letter corresponding to the correct answer.
# ###
# Passage: {{flores_passage}}
# ###
# Query: {{question}}
# ###
# Choices:
# {% set choices = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}
# {% for choice in choices %}
# {{ answer_choices[loop.index0] }}. {{choice}}
# {% endfor %}
# ###
# Answer:
# |||
# {{ answer_choices[correct_answer_num|int-1] }}
# --------------------------------------------------------------------------------
# Skipping prompt 14854 - results already exist
# |        Tasks        |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |belebele_prompt_14854|      1|none  |     0|acc     |↑  |0.3967|±  |0.0163|
# |                     |       |none  |     0|acc_norm|↑  |0.3967|±  |0.0163|
#
# --------------------------------------------------------------------------------
#
# Processing prompt 2/5 (ID: 14853)
# Template: Consider the following question:
# {{question}}
# with the following context:
# {{flores_passage}}
# Please answer the question selecting one of these answers:
# {% set choices = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}
# {% for choice in choices %}
# {{ answer_choices[loop.index0] }}. {{choice}}
# {% endfor %}
# |||
# {{ answer_choices[correct_answer_num|int-1] }}
# --------------------------------------------------------------------------------
# Skipping prompt 14853 - results already exist
# |        Tasks        |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |belebele_prompt_14853|      1|none  |     0|acc     |↑  |0.2722|±  |0.0148|
# |                     |       |none  |     0|acc_norm|↑  |0.2722|±  |0.0148|
#
# --------------------------------------------------------------------------------
#
# Processing prompt 3/5 (ID: 14801)
# Template: Read the following Passage: {{flores_passage}},
# Then answer the question: {{question}}
# Choices:
# {% set answer_keys = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}
# {% for answer in answer_keys %}
# {{ answer_choices[loop.index0] }}. {{ answer_keys[loop.index0] }} {% endfor %}
# Your answer is:
# |||
# {{ answer_choices[correct_answer_num | int-1 ] }}
# --------------------------------------------------------------------------------
# Skipping prompt 14801 - results already exist
# |        Tasks        |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |belebele_prompt_14801|      1|none  |     0|acc     |↑  |0.4256|±  |0.0165|
# |                     |       |none  |     0|acc_norm|↑  |0.4256|±  |0.0165|
#
# --------------------------------------------------------------------------------
#
# Processing prompt 4/5 (ID: 14800)
# Template: Passage: {{flores_passage}}
# Queion: {{question}}
# Choices:
# {% set answer_keys = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}
# {% for answer in answer_keys %}
# {{ answer_choices[loop.index0] }}. {{ answer_keys[loop.index0] }} {% endfor %}
# Answer:
# |||
# {{ answer_choices[correct_answer_num | int -1] }}
# --------------------------------------------------------------------------------
# Skipping prompt 14800 - results already exist
# |        Tasks        |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |belebele_prompt_14800|      1|none  |     0|acc     |↑  |0.3989|±  |0.0163|
# |                     |       |none  |     0|acc_norm|↑  |0.3989|±  |0.0163|
#
# --------------------------------------------------------------------------------
#
# Processing prompt 5/5 (ID: 14575)
# Template: Given the following document : {{flores_passage}} and the question {{question}} and the following options: {{answer_choices[0]}}. {{mc_answer1}} {{answer_choices[1]}}. {{mc_answer2}} {{answer_choices[2]}}. {{mc_answer3}} {{answer_choices[3]}}. {{mc_answer4}}, the correct answer is:
# |||
# {{answer_choices[correct_answer_num | int-1]}}
# --------------------------------------------------------------------------------
# Skipping prompt 14575 - results already exist
# |        Tasks        |Version|Filter|n-shot| Metric |   |Value|   |Stderr|
# |---------------------|------:|------|-----:|--------|---|----:|---|-----:|
# |belebele_prompt_14575|      1|none  |     0|acc     |↑  | 0.26|±  |0.0146|
# |                     |       |none  |     0|acc_norm|↑  | 0.26|±  |0.0146|

# %%
exit()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
