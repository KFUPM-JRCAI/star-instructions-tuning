# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2,3'
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import lm_eval
from lm_eval.tasks import TaskManager
from lm_eval.evaluator import simple_evaluate
from lm_eval.utils import make_table

# %% [markdown]
# # Constants

# %%
TAWJEEH_DATASET_NAME = 'belebele'
HF_EXPERIMENTAL_DATASET_NAME = 'KFUPM-JRCAI/belebele_experimental'
TASK_NAME='NLU'
MODEL_PATH = "/raid_storage/shared_models/Meta-Llama-3.1-8B"
TUNED_MODEL_PATH = None
BATCH_SIZE=40

# %%
MODEL_NAME = MODEL_PATH.split('/')[-1]
TOKENIZER_PATH = MODEL_PATH

# %% [markdown]
# # Building the prompts dataset

# %%
import requests
 
from tqdm.auto import tqdm
 
prompts = None
 
tries = 10
for i in tqdm(range(tries)):
    api_response = requests.get(url='https://promptlab.up.railway.app/api/prompt/list?project_secret_key=6Wirj')
    if api_response.ok:
        prompts = api_response.json()
        break
if not prompts:
    raise Exception('Failed to fetch prompts')
prompts[:5]
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# [{'id': 14888,
#   'tags': ['AI generated'],
#   'name': 'history_based_dialect',
#   'task': {'name': 'dialect identification'},
#   'status': 'SUBMITTED',
#   'template': 'Consider this historical context in the text provided: {{Text}}. Which dialect from the ancient regions does it emerge from? Select from these regions: Levant, North Africa, Egypt, GULF, MSA. ||| {{answer_choices[label]}}',
#   'dataset_name': 'arbml/Arabic_Dialects_Dataset',
#   'dataset_subset': 'default',
#   'answer_choices': ['Levant', 'North Africa', 'Egypt', 'GULF', 'MSA'],
#   'text_direction': 'ltr'},
#  {'id': 14887,
#   'tags': ['AI generated'],
#   'name': 'literary_style_identification',
#   'task': {'name': 'dialect identification'},
#   'status': 'SUBMITTED',
#   'template': 'The narrative style found in the following phrase: {{Text}}, is tied to a specific dialect. Out of Levant, North Africa, Egypt, GULF, MSA, which one do you think it is? ||| {{answer_choices[label]}}',
#   'dataset_name': 'arbml/Arabic_Dialects_Dataset',
#   'dataset_subset': 'default',
#   'answer_choices': ['Levant', 'North Africa', 'Egypt', 'GULF', 'MSA'],
#   'text_direction': 'ltr'},
#  {'id': 14886,
#   'tags': [],
#   'name': 'EmotionClassification-Steps Prompt-Updated',
#   'task': {'name': 'emotion classification'},
#   'status': 'SUBMITTED',
#   'template': 'Task: Read the tweet below and decide which emotion it expresses. The possible emotions are {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}.\r\n\r\nTweet: {{ tweet }}\r\n\r\nSteps:\r\n1. Look for Emotional Words: Identify any words in the tweet that hint at a specific emotion.\r\n2. Decide the Mood: Is the mood positive, negative, or neutral?\r\n3. Pick the Emotion: Choose the emotion that best matches the mood.\r\n\r\n Answer: Provide the emotion {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %} based on the steps. Do not include any additional explanation.\r\n|||\r\n{{ answer_choices[label] }}',
#   'dataset_name': 'emotone_ar',
#   'dataset_subset': 'default',
#   'answer_choices': ['none',
#    'anger',
#    'joy',
#    'sadness',
#    'love',
#    'sympathy',
#    'surprise',
#    'fear'],
#   'text_direction': 'ltr'},
#  {'id': 14885,
#   'tags': [],
#   'name': 'EmotionClassification-Expert In Identifying Emotion Prompt-Updated',
#   'task': {'name': 'emotion classification'},
#   'status': 'SUBMITTED',
#   'template': 'Imagine you are an emotion expert analyzing the following tweet. Carefully read the tweet and use your expertise to determine the emotion being expressed. The possible emotions are {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}.\r\n\r\nTweet: {{ tweet }}\r\n\r\nExpert Approach:\r\n1. Identify Emotional Cues: Look for any words or phrases in the tweet that suggest an emotional state. Think about what kind of feelings these words evoke.\r\n2. Assess the Overall Mood: Consider the mood created by the language used. Is the tweet conveying positive or negative emotions, or is it neutral?\r\n3. Choose the Emotion: Based on the emotional cues and overall mood, decide which emotion from the list fits best.\r\n\r\nAnswer: Provide the most appropriate emotion using your expert analysis  {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}. Do not include any additional explanation.\r\n|||\r\n{{ answer_choices[label]}}',
#   'dataset_name': 'emotone_ar',
#   'dataset_subset': 'default',
#   'answer_choices': ['none',
#    'anger',
#    'joy',
#    'sadness',
#    'love',
#    'sympathy',
#    'surprise',
#    'fear'],
#   'text_direction': 'ltr'},
#  {'id': 14884,
#   'tags': [],
#   'name': 'EmotionClassification-COT Prompt-Updated',
#   'task': {'name': 'emotion classification'},
#   'status': 'SUBMITTED',
#   'template': 'Follow the steps below to classify the emotion expressed in the tweet. The possible emotions are {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}.\r\n\r\nTweet: {{ tweet }}\r\n\r\nStep 1: Interpret the Content: Carefully read the tweet and identify any expressions or language that hint at a specific emotion.\r\nStep 2: Analyze the Emotional Tone: Assess the emotional tone by considering whether the content conveys positive, negative, or neutral feelings.\r\nStep 3: Match with the Emotion List: Compare the emotional tone with the list of possible emotions and choose the one that best aligns with the mood expressed in the tweet.\r\n\r\nAnswer: Provide the most appropriate emotion {% for choice in answer_choices %}{{ choice }}{% if not loop.last %} or {% endif %}{% endfor %}. Do not include any additional explanation.\r\n|||\r\n{{ answer_choices[label] }}',
#   'dataset_name': 'emotone_ar',
#   'dataset_subset': 'default',
#   'answer_choices': ['none',
#    'anger',
#    'joy',
#    'sadness',
#    'love',
#    'sympathy',
#    'surprise',
#    'fear'],
#   'text_direction': 'ltr'}]

# %% [markdown]
# filter prompts:
# - get only the approved ones
# - get only the ones on the sarcasim detection datasets (emotone_ar,sem_eval_2018_task_1)

# %%
filtered_prompts = list(filter(lambda prompt: prompt['status'] == 'APPROVED' and prompt['text_direction'].lower() == 'ltr', prompts))
len(filtered_prompts)
# Out:
# 223

# %% [markdown]
# ### Get the dataset prompts

# %%
# you can either filter by task or dataset
dataset_prompts = list(
    filter(
        lambda prompt: TAWJEEH_DATASET_NAME in prompt['dataset_name'],
        filtered_prompts,
    )
)
len(dataset_prompts)
# Out:
# 5

# %%
SELECTED_PROMPTS_IDS = [
    14854,
    14853,   
    14801,
    14800,
    14575,
]

# %%
dataset_prompts = list(filter(lambda prompt: prompt['id'] in SELECTED_PROMPTS_IDS, filtered_prompts))
len(dataset_prompts)
# Out:
# 5

# %% [markdown]
# ### Download the dataset

# %%
import datasets

# %%
hf_exp_dataset = datasets.load_dataset(HF_EXPERIMENTAL_DATASET_NAME)
hf_exp_dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['link', 'question_number', 'flores_passage', 'question', 'mc_answer1', 'mc_answer2', 'mc_answer3', 'mc_answer4', 'correct_answer_num', 'dialect', 'ds'],
#         num_rows: 900
#     })
# })

# %% [markdown]
# ### Merge the prompts

# %%
from jinja2 import Environment, StrictUndefined

# %%
def apply_template(prompt_template, sample):
    try:
        template = prompt_template['template']
        sample['answer_choices'] = prompt_template['answer_choices']
        env = Environment(undefined=StrictUndefined)
        if "|||" not in template:
            raise ValueError("No ||| dividor")
        template = env.from_string(template)
        rendered_template = template.render(**sample)
        return rendered_template
    except Exception as e:
        print(prompt_template)
        print(sample)
        raise e

# %% [markdown]
# Perform generation on one example prompt, for experimentation

# %%
example_prompt_template = dataset_prompts[0]
print(apply_template(example_prompt_template, hf_exp_dataset['test'][1]))
# Out:
# Given the following passage, query, and answer choices, output the letter corresponding to the correct answer.
# ###
# Passage: """جزر كوك هي دولة جزرية مرتبطة بشكل حر بنيوزيلندا، وتصير ببولينيزيا وسط جنوب المحيط الهادئ. هي أرخبيل بي 15 جزيرة منتشرة على مساحة تزيد عن 2.2 مليون كيلومتر مربع من المحيط. تتشارك بنفس المنطقة الزمنية مثل هاواي، وتعتبر أحياناً هذي الجزر بأنها """"هاواي أسفل"""". على الرغم من كونها أصغر بالحجم، بس تذكر بعض الزائرين القدامى اللي جايين من هاواي ما قبل قيام الدولة قبل وجود كل الفنادق السياحية الكبيرة وغيرها من التطويرات. ماكو بجزر كوك أي مدن بس تتكون من 15 جزيرة أهمها راروتونجا وإيتوتاكي."""
# ###
# Query: أي من التالي ما يوصف جزر كوك بشكل دقيق؟
# ###
# Choices:
#
#
# A. اصغر من هاواي
#
# B. عبارة عن أرخبيل
#
# C. مدنها الرئيسية هي راروتونجا وإيتوتاكي
#
# D. البلد الجزري يتشارك نفس المنطقة الزمنيه ويه هاواي
#
# ###
# Answer:
# |||
# C

# %% [markdown]
# merge prompts

# %%
for prompt in dataset_prompts:
    prompt['merged_samples'] = list(
        map(
            lambda sample: apply_template(prompt, sample),
            # hf_exp_dataset['test'].select(range(100)),
            tqdm(hf_exp_dataset['test']),
        )
    )
    prompt['original_samples'] = list(hf_exp_dataset['test'])
# Out:
#   0%|          | 0/900 [00:00<?, ?it/s]
#   0%|          | 0/900 [00:00<?, ?it/s]
#   0%|          | 0/900 [00:00<?, ?it/s]
#   0%|          | 0/900 [00:00<?, ?it/s]
#   0%|          | 0/900 [00:00<?, ?it/s]

# %% [markdown]
# # Evaluate on each prompt and report the results

# %%
from datasets import DatasetDict
import re

def create_hf_dataset(dataset_prompt, columns=None):
  if columns is None:
    columns = ['text', 'label','choices']
  texts = []
  labels = []
  choices = []
  for i,merged_sample in enumerate(dataset_prompt['merged_samples']):
    # prefix= merged_sample.split('|||')[0].replace('\n', ' ')
    prefix= merged_sample.split('|||')[0]
    # remove multi spaces
    # prefix = re.sub(r'\s+', ' ', prefix)
    prefix = prefix.strip()
    # add new line after prefx (this turns out to have a large effect on some prompts)
    # prefix = prefix+'\n'
    output = merged_sample.split('|||')[1].replace('\n', '').strip()
    example_choices = dataset_prompt['answer_choices']
    texts.append(prefix)
    labels.append(output)
    choices.append(example_choices)
  dataset = DatasetDict({ 'test' : datasets.Dataset.from_dict({
      columns[0]: texts,
      columns[1]: labels,
      columns[2]: choices,
  })})
  return dataset

# %%
dataset = create_hf_dataset(dataset_prompts[0])
dataset['test'][1]['text']
# Out:
# 'Given the following passage, query, and answer choices, output the letter corresponding to the correct answer.\n###\nPassage: """جزر كوك هي دولة جزرية مرتبطة بشكل حر بنيوزيلندا، وتصير ببولينيزيا وسط جنوب المحيط الهادئ. هي أرخبيل بي 15 جزيرة منتشرة على مساحة تزيد عن 2.2 مليون كيلومتر مربع من المحيط. تتشارك بنفس المنطقة الزمنية مثل هاواي، وتعتبر أحياناً هذي الجزر بأنها """"هاواي أسفل"""". على الرغم من كونها أصغر بالحجم، بس تذكر بعض الزائرين القدامى اللي جايين من هاواي ما قبل قيام الدولة قبل وجود كل الفنادق السياحية الكبيرة وغيرها من التطويرات. ماكو بجزر كوك أي مدن بس تتكون من 15 جزيرة أهمها راروتونجا وإيتوتاكي."""\n###\nQuery: أي من التالي ما يوصف جزر كوك بشكل دقيق؟\xa0\n###\nChoices:\n\n\nA. اصغر من هاواي\n\nB. عبارة عن أرخبيل \n\nC. مدنها الرئيسية هي راروتونجا وإيتوتاكي\n\nD. البلد الجزري يتشارك نفس المنطقة الزمنيه ويه هاواي\n\n###\nAnswer:'

# %%
from lm_eval.models.huggingface import HFLM
if 'lm_obj' not in locals():
    lm_obj = HFLM(
        pretrained=MODEL_PATH,
        trust_remote_code=True,
        parallelize=True,
        device_map="auto",
        tokenizer=TOKENIZER_PATH,
        batch_size=BATCH_SIZE,
    )
# Out:
# 2024-11-28:10:36:43,471 INFO     [huggingface.py:483] Using model type 'default'
# 2024-11-28:10:36:44,229 INFO     [huggingface.py:350] Model parallel was set to True, setting max memory per GPU to {0: 84523417600, 1: 84523417600} and device map to 'auto'
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
def evaluate_tasks(tasks,dataset_sub_path=TAWJEEH_DATASET_NAME):
    # MAKE SURE THE NOTEBOOK IS RUNNING FROM THE PROJECT ROOT!
    task_manager = TaskManager(include_path=f"eval_harness_extra_tasks/{dataset_sub_path}")
    results = simple_evaluate(  # call simple_evaluate
        model=lm_obj,
        tasks=tasks,
        num_fewshot=0,
        task_manager=task_manager,
    )
    return results

# %%
import json

def create_and_evaluate_single_prompt(prompt, save_results=True, force_re_evaluate=False):
    prompt_id = prompt['id']
    if TUNED_MODEL_PATH:
        results_dir = f'evaluation_results/{MODEL_NAME}-tuned/{TASK_NAME}/{TAWJEEH_DATASET_NAME}'
    else:
        results_dir = f'evaluation_results/{MODEL_NAME}/{TASK_NAME}/{TAWJEEH_DATASET_NAME}'
    prompt_results_file_path = f'{results_dir}/prompt_{prompt_id}.json'
    
    # Check if results exist and handle based on parameters
    if os.path.exists(prompt_results_file_path) and os.path.getsize(prompt_results_file_path) > 0:
        if not force_re_evaluate:
            print(f"Skipping prompt {prompt_id} - results already exist")
            with open(prompt_results_file_path, 'r') as f:
                prompt_results = json.load(f)
                print(make_table(prompt_results))
                return prompt_results
        else:
            print(f"Force re-evaluate enabled - reevaluating prompt {prompt_id}")
    
    # Create dataset and task files
    dataset = create_hf_dataset(prompt)
    
    # Save dataset
    dataset_dir = f'experimental_hf_datasets/{TAWJEEH_DATASET_NAME}/prompt_{prompt_id}'
    os.makedirs(dataset_dir, exist_ok=True)
    dataset['test'].to_parquet(f"{dataset_dir}/data.parquet")
    
    # Create YAML configuration
    yaml_text = f'''task: {TAWJEEH_DATASET_NAME}_prompt_{prompt_id}
dataset_path: experimental_hf_datasets/{TAWJEEH_DATASET_NAME}/prompt_{prompt_id}
output_type: multiple_choice
test_split: train
doc_to_text: text
doc_to_choice: choices
doc_to_target: label
metric_list:
  - metric: acc
    aggregation: mean
    higher_is_better: True
  - metric: acc_norm
    aggregation: mean
    higher_is_better: true
metadata:
  version: 1.0'''
    
    # Save YAML
    yaml_dir = f'eval_harness_extra_tasks/{TAWJEEH_DATASET_NAME}'
    os.makedirs(yaml_dir, exist_ok=True)
    with open(f'{yaml_dir}/prompt_{prompt_id}.yaml', 'w') as f:
        f.write(yaml_text)
    
    # Evaluate single prompt
    evaluation_task_name = f'{TAWJEEH_DATASET_NAME}_prompt_{prompt_id}'
    prompt_results = evaluate_tasks(tasks=[evaluation_task_name])
    
    print(make_table(prompt_results))
    
    # Save results if save_results is True
    if save_results:
        os.makedirs(results_dir, exist_ok=True)
        with open(prompt_results_file_path, 'w') as f:
            json.dump(prompt_results, f, ensure_ascii=False, indent=4, 
                     default=lambda o: '<not serializable>')
        print(f"Saved results for prompt {prompt_id}")
    else:
        print(f"Results not saved for prompt {prompt_id} (save_results=False)")
    
    print(f"Completed evaluation for prompt {prompt_id}")
    return prompt_results

# %%
def evaluate_all_prompts_sequentially(dataset_prompts):
    print(f"Starting sequential evaluation of {len(dataset_prompts)} prompts")
    all_results = {}
    
    for i, prompt in enumerate(dataset_prompts, 1):
        print('-' * 80)
        print(f"\nProcessing prompt {i}/{len(dataset_prompts)}")
        print("Template:", prompt['template'])
        print('-' * 80)
        
        prompt_results = create_and_evaluate_single_prompt(prompt)
        all_results[f"{TAWJEEH_DATASET_NAME}_prompt_{prompt['id']}"] = prompt_results
    
    return {'results': all_results}

# %%
all_results = evaluate_all_prompts_sequentially(dataset_prompts=dataset_prompts)
# Out:
# Starting sequential evaluation of 5 prompts
# --------------------------------------------------------------------------------
#
# Processing prompt 1/5
# Template: Given the following passage, query, and answer choices, output the letter corresponding to the correct answer.
# ###
# Passage: {{flores_passage}}
# ###
# Query: {{question}}
# ###
# Choices:
# {% set choices = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}
# {% for choice in choices %}
# {{ answer_choices[loop.index0] }}. {{choice}}
# {% endfor %}
# ###
# Answer:
# |||
# {{ answer_choices[correct_answer_num|int-1] }}
# --------------------------------------------------------------------------------
# Skipping prompt 14854 - results already exist
# |        Tasks        |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |belebele_prompt_14854|      1|none  |     0|acc     |↑  |0.5289|±  |0.0166|
# |                     |       |none  |     0|acc_norm|↑  |0.5289|±  |0.0166|
#
# --------------------------------------------------------------------------------
#
# Processing prompt 2/5
# Template: Consider the following question:
# {{question}}
# with the following context:
# {{flores_passage}}
# Please answer the question selecting one of these answers:
# {% set choices = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}
# {% for choice in choices %}
# {{ answer_choices[loop.index0] }}. {{choice}}
# {% endfor %}
# |||
# {{ answer_choices[correct_answer_num|int-1] }}
# --------------------------------------------------------------------------------
# Skipping prompt 14853 - results already exist
# |        Tasks        |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |belebele_prompt_14853|      1|none  |     0|acc     |↑  |0.2622|±  |0.0147|
# |                     |       |none  |     0|acc_norm|↑  |0.2622|±  |0.0147|
#
# --------------------------------------------------------------------------------
#
# Processing prompt 3/5
# Template: Read the following Passage: {{flores_passage}},
# Then answer the question: {{question}}
# Choices:
# {% set answer_keys = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}
# {% for answer in answer_keys %}
# {{ answer_choices[loop.index0] }}. {{ answer_keys[loop.index0] }} {% endfor %}
# Your answer is:
# |||
# {{ answer_choices[correct_answer_num | int-1 ] }}
# --------------------------------------------------------------------------------
# Skipping prompt 14801 - results already exist
# |        Tasks        |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |belebele_prompt_14801|      1|none  |     0|acc     |↑  |0.5011|±  |0.0167|
# |                     |       |none  |     0|acc_norm|↑  |0.5011|±  |0.0167|
#
# --------------------------------------------------------------------------------
#
# Processing prompt 4/5
# Template: Passage: {{flores_passage}}
# Queion: {{question}}
# Choices:
# {% set answer_keys = [mc_answer1, mc_answer2, mc_answer3, mc_answer4] %}
# {% for answer in answer_keys %}
# {{ answer_choices[loop.index0] }}. {{ answer_keys[loop.index0] }} {% endfor %}
# Answer:
# |||
# {{ answer_choices[correct_answer_num | int -1] }}
# --------------------------------------------------------------------------------
# Skipping prompt 14800 - results already exist
# |        Tasks        |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |belebele_prompt_14800|      1|none  |     0|acc     |↑  |0.4911|±  |0.0167|
# |                     |       |none  |     0|acc_norm|↑  |0.4911|±  |0.0167|
#
# --------------------------------------------------------------------------------
#
# Processing prompt 5/5
# Template: Given the following document : {{flores_passage}} and the question {{question}} and the following options: {{answer_choices[0]}}. {{mc_answer1}} {{answer_choices[1]}}. {{mc_answer2}} {{answer_choices[2]}}. {{mc_answer3}} {{answer_choices[3]}}. {{mc_answer4}}, the correct answer is:
# |||
# {{answer_choices[correct_answer_num | int-1]}}
# --------------------------------------------------------------------------------
# Skipping prompt 14575 - results already exist
# |        Tasks        |Version|Filter|n-shot| Metric |   |Value|   |Stderr|
# |---------------------|------:|------|-----:|--------|---|----:|---|-----:|
# |belebele_prompt_14575|      1|none  |     0|acc     |↑  | 0.45|±  |0.0166|
# |                     |       |none  |     0|acc_norm|↑  | 0.45|±  |0.0166|

# %%
exit()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
