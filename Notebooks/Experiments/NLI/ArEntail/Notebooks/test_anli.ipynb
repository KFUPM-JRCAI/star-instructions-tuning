# %%
# !lm_eval --model hf \
    --model_args pretrained=/hdd/shared_models/Meta-Llama-3.1-8B-Instruct,parallelize=True \
    --tasks anli \
    --batch_size auto \
    --num_fewshot 0
# Out:
# 2024-11-17:14:30:23,401 INFO     [__main__.py:279] Verbosity set to INFO
# 2024-11-17:14:30:30,083 INFO     [__main__.py:376] Selected Tasks: ['anli']
# 2024-11-17:14:30:30,085 INFO     [evaluator.py:164] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2024-11-17:14:30:30,085 INFO     [evaluator.py:201] Initializing hf model, with arguments: {'pretrained': '/hdd/shared_models/Meta-Llama-3.1-8B-Instruct', 'parallelize': True}
# 2024-11-17:14:30:30,526 INFO     [huggingface.py:483] Using model type 'default'
# 2024-11-17:14:30:37,480 INFO     [huggingface.py:350] Model parallel was set to True, setting max memory per GPU to {0: 84523417600, 1: 84523417600, 2: 84523417600, 3: 84523417600, 4: 84523417600, 5: 84523417600, 6: 84523417600, 7: 84523417600} and device map to 'auto'
# Loading checkpoint shards: 100%|██████████████████| 4/4 [00:06<00:00,  1.65s/it]
# ...
